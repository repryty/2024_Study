# %%
# !pip3 install pillow
# !pip3 install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.1.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\users\user\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.1.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\users\user\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import random
import copy

# %%
image=np.array(Image.open("test.jpg"))
len(image[0][0]) # 512x512x3
plt.imshow(np.array([[[random.choice([0,255])]*3 for ii in range(300)] for iii in range(300)]))
plt.show()

# %%
state = np.array([[[random.choice([0,255])]*3 for ii in range(10)] for iii in range(10)]) # 512x512의 노이즈 이미지

original_state = copy.copy(state)
state = np.rot90(state, random.randint(0, 3))

# %%
state = np.rot90(state, 2)

# %%
plt.imshow(state)
plt.show()

# %%
plt.imshow(original_state)
plt.show()
